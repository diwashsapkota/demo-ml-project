# %% [markdown]
# <a href="https://colab.research.google.com/github/diwashsapkota/demo-ml-project/blob/main/demo_ml_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Importing Dataset**

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/diwashsapkota/demo-ml-project/main/delaney_solubility_with_descriptors.csv')
df.head()
# Out:
#    MolLogP    MolWt  NumRotatableBonds  AromaticProportion  logS
# 0   2.5954  167.850                0.0                 0.0 -2.18
# 1   2.3765  133.405                0.0                 0.0 -2.00
# 2   2.5938  167.850                1.0                 0.0 -1.74
# 3   2.0289  133.405                1.0                 0.0 -1.48
# 4   2.9189  187.375                1.0                 0.0 -3.04

# %% [markdown]
# #**Preparing Data**

# %% [markdown]
# ## Data Separation as x and y

# %%
y = df['logS']
y
# Out:
# 0      -2.180
# 1      -2.000
# 2      -1.740
# 3      -1.480
# 4      -3.040
#         ...
# 1139    1.144
# 1140   -4.925
# 1141   -3.893
# 1142   -3.790
# 1143   -2.581
# Name: logS, Length: 1144, dtype: float64

# %%
x = df.drop('logS', axis=1) 
#axis=1 will allow the drop function to work with the data as column
#axis=0 would work in the row mode
x
# Out:
#       MolLogP    MolWt  NumRotatableBonds  AromaticProportion
# 0     2.59540  167.850                0.0            0.000000
# 1     2.37650  133.405                0.0            0.000000
# 2     2.59380  167.850                1.0            0.000000
# 3     2.02890  133.405                1.0            0.000000
# 4     2.91890  187.375                1.0            0.000000
# ...       ...      ...                ...                 ...
# 1139  1.98820  287.343                8.0            0.000000
# 1140  3.42130  286.114                2.0            0.333333
# 1141  3.60960  308.333                4.0            0.695652
# 1142  2.56214  354.815                3.0            0.521739
# 1143  2.02164  179.219                1.0            0.461538
#
# [1144 rows x 4 columns]

# %% [markdown]
# ### Data Splitting

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=1-00)

# %%
x_train
# Out:
#       MolLogP    MolWt  NumRotatableBonds  AromaticProportion
# 226   1.74850   68.119                1.0            0.000000
# 774   2.66980  154.253                4.0            0.000000
# 683   3.61302  278.335                5.0            0.375000
# 535   1.31140  100.161                0.0            0.000000
# 335  -0.06520  182.179                2.0            0.000000
# ...       ...      ...                ...                 ...
# 715   2.50850  197.381                0.0            0.000000
# 905   0.10710  219.266                1.0            0.000000
# 1096  2.99000  246.359                7.0            0.000000
# 235   2.05240   72.151                1.0            0.000000
# 1061  5.60150  365.964                5.0            0.315789
#
# [915 rows x 4 columns]

# %%
x_test
# Out:
#       MolLogP    MolWt  NumRotatableBonds  AromaticProportion
# 382  -3.10802  457.432                7.0            0.187500
# 677   2.84032  201.225                2.0            0.733333
# 516   2.87800  152.237                4.0            0.000000
# 963   6.29940  278.354                0.0            1.000000
# 1098  1.74810   84.143                0.0            1.000000
# ...       ...      ...                ...                 ...
# 191   3.60230  207.070                0.0            0.909091
# 701   1.62620  221.260                3.0            0.375000
# 348   0.42840  162.152                1.0            0.833333
# 863   2.65122  266.304                1.0            0.600000
# 748   3.18870  313.747                7.0            0.277778
#
# [229 rows x 4 columns]

# %% [markdown]
# # **Model Building**

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ### Training the model

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### Applying the model to make prediction

# %%
y_lr_train_pred = lr.predict(x_train)
y_lr_test_pred = lr.predict(x_test)

# %%
y_lr_train_pred
# Out:
# array([-1.47807343e+00, -2.70056767e+00, -4.36904387e+00, -1.37063241e+00,
#        -9.03795451e-01, -5.48741561e+00, -4.52228625e+00,  1.64842498e+00,
#        -3.96019064e+00, -2.66038569e+00, -2.02009065e+00, -2.06838896e+00,
#        -1.59515638e+00, -2.44969941e+00, -1.50829669e+00, -1.97171362e+00,
#        -2.06940552e+00, -4.16316074e+00, -3.18534227e+00, -3.11536287e+00,
#        -2.12953787e+00, -3.91183801e+00, -5.42018926e+00, -1.64377489e+00,
#        -3.33660820e+00, -8.83398573e-01, -3.24076978e+00, -4.21747153e-01,
#        -5.57650052e+00, -1.72433644e+00, -3.14331582e+00, -2.41192013e+00,
#        -2.99292535e+00, -6.04304264e+00, -5.25186506e+00, -6.05539535e+00,
#        -5.75052073e+00, -4.65323063e+00, -3.04450190e+00, -3.90041247e+00,
#        -4.14723416e+00, -2.23741541e+00, -6.04572794e+00, -1.59287707e+00,
#        -3.70950157e+00, -2.71859438e+00, -7.94901291e+00, -1.91755463e+00,
# ...

# %%
y_lr_test_pred
# Out:
# array([-5.71696348e-01, -3.48623578e+00, -2.83823195e+00, -6.62259837e+00,
#        -2.06720083e+00, -2.79532950e+00, -7.02354922e+00, -4.29706753e+00,
#        -5.48741561e+00, -5.20868339e+00, -2.48439272e-01, -3.79586087e+00,
#        -1.65219841e+00, -1.75615460e+00, -5.17832296e+00, -1.46364807e+00,
#        -1.08291383e+00, -1.93183979e+00, -4.48640248e+00, -3.41999575e+00,
#        -7.02354922e+00, -2.56938112e+00, -4.15058397e+00, -2.63390050e+00,
#        -4.12449121e+00, -1.93074349e+00, -5.22737547e-01, -1.82369562e+00,
#        -6.63557950e+00, -2.61563026e+00, -2.96599075e+00, -4.89748000e+00,
#        -4.72043610e+00, -1.80141422e+00, -3.93796519e+00, -1.32261377e+00,
#        -3.79761504e+00, -3.93991263e+00, -5.09425691e+00, -3.68834966e+00,
#        -4.34244581e+00, -1.01084332e+00, -5.16688515e-01, -2.55032112e+00,
#        -7.51743308e-01, -1.93072468e+00, -3.16629553e+00, -3.02602805e+00,
# ...

# %% [markdown]
# ###Evaluate Model Performance

# %%
from sklearn.metrics import mean_squared_error, r2_score

lr_train_mse = mean_squared_error(y_train, y_lr_train_pred)
lr_train_r2 = r2_score(y_train, y_lr_train_pred)

lr_test_mse = mean_squared_error(y_test, y_lr_test_pred)
lr_test_r2 = r2_score(y_test, y_lr_test_pred)

# %%
lr_results = pd.DataFrame(['Linear regression', lr_train_mse, lr_train_r2, lr_test_mse, lr_test_r2]).transpose()
lr_results.columns = ['Method', 'Training MSE', 'Training R2', 'Test MSE', 'Test R2']

# %%
lr_results
# Out:
#               Method Training MSE Training R2  Test MSE  Test R2
# 0  Linear regression       1.0319    0.759261  0.928447  0.80697

# %% [markdown]
# ## Random Forest

# %% [markdown]
# ### Training the Model

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor(max_depth = 2, random_state=00)
rf.fit(x_train, y_train)
# Out:
# RandomForestRegressor(max_depth=2, random_state=0)

# %% [markdown]
# ### Applying the model to make prediction

# %%
y_rf_train_pred = rf.predict(x_train)
y_rf_test_pred = rf.predict(x_test)

# %% [markdown]
# ### Evaluate Model Performance

# %%
from sklearn.metrics import mean_squared_error, r2_score

rf_train_mse = mean_squared_error(y_train, y_rf_train_pred)
rf_train_r2 = r2_score(y_train, y_rf_train_pred)

rf_test_mse = mean_squared_error(y_test, y_rf_test_pred)
rf_test_r2 = r2_score(y_test, y_rf_test_pred)

# %%
rf_results = pd.DataFrame(['Random Forest', rf_train_mse, rf_train_r2, rf_test_mse, rf_test_r2]).transpose()
rf_results.columns = ['Method', 'Training MSE', 'Training R2', 'Test MSE', 'Test R2']
rf_results
# Out:
#           Method Training MSE Training R2  Test MSE   Test R2
# 0  Random Forest     1.069729    0.750436  1.056702  0.780305

# %% [markdown]
# ## Model Comparison

# %%
df_models = pd.concat([lr_results, rf_results], axis=0)
df_models
# Out:
#               Method Training MSE Training R2  Test MSE   Test R2
# 0  Linear regression       1.0319    0.759261  0.928447   0.80697
# 0      Random Forest     1.069729    0.750436  1.056702  0.780305

# %%
df_models.reset_index(drop=True)
# Out:
#               Method Training MSE Training R2  Test MSE   Test R2
# 0  Linear regression       1.0319    0.759261  0.928447   0.80697
# 1      Random Forest     1.069729    0.750436  1.056702  0.780305

# %% [markdown]
# # **Data Visualization**

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(5,5))
plt.scatter(x=y_train, y=y_lr_train_pred, c='#7CAE00', alpha=0.3)

x=np.polyfit(y_train, y_lr_train_pred, 1)
p = np.poly1d(x)

plt.plot(y_train, p(y_train), '#F8766D')
plt.ylabel('Predict LogS')
plt.xlabel('Experimental LogS')
# Out:
# Text(0.5, 0, 'Experimental LogS')
